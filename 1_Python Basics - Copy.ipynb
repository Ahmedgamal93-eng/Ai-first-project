# %%
print("Hello")

int str float bool
x=5
print(x)
name='ali'
# Out:
# Hello

# %%
print("Hello Data Science")
print(123)
# Out:
# Hello Data Science
# 123

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Python Basics
#
# This is the first session of Data Science

# %%
print("Hello World\n") # escape chracter
print("Hello World")
# Out:
# Hello World
#
# Hello World

# %%
print(''' I'm 25 "years" old """ HELLO """ ''')
# Out:
#  I'm 25 "years" old """ HELLO """

# %%
print('''Hello , My name is Mohamed.
I work as Big Data Engineer.
	I Love Ai.''')
# Out:
# Hello , My name is Mohamed.
# I work as Big Data Engineer.
# 	I Love Ai.

# %%
print("Hello\nWorld")   # new line character \n
# Out:
# Hello
# World

# %%
print("Hello\tWorld")  # horizontal tab
# Out:
# Hello	World

# %%
5*10+15
# Out:
# 65

# %% [markdown]
# # ***Hello***
#
#
#
# *   List item
# *   List item
#
#
# 1.   List item
# 2.   List item
#
#
#
# > Indented block
#
#
# ---
#
#
# [link text](https://)

# %% [markdown]
# # Variables

# %%
x = 20

# %%
x = 10
print(x)
print(type(x))
# Out:
# 10
# <class 'int'>

# %%
b = 10.5
print(b)
print(type(b))
# Out:
# 10.5
# <class 'float'>

# %%
c = "Indore"
print(c)
print(type(c))
# Out:
# Indore
# <class 'str'>

# %%
a = 10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 10.5
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Anas"
print(type(c))
# Out:
# <class 'str'>

# %%
d = '10'
print(d)
print(type(d))
num=10
print(type(num))
# Out:
# 10
# <class 'str'>
# <class 'int'>

# %%
h="y"

# %%
h = 10
h=h+3
print(h)
print(type(h))
h = "H"
print(type(h))

print(h)
# Out:
# 13
# <class 'int'>
# <class 'str'>
# H

# %%
print(h)
# Out:
# H

# %%
Aka = 10
aka = 52
print(Aka)
print(aka)
# Out:
# 10
# 52

# %% [markdown]
# # User Input

# %%
y  = a*x+b

# %%
num = int(input() )
print(num)
type(num)
# Out:
# 5
# 5
# int

# %%
print(num)
print(type(num))
# Out:
# 400
# <class 'str'>

# %%
y = int(num)
print(y)
print(type(y))
# Out:
# 400
# <class 'int'>

# %%
print(type(x))
# Out:
# <class 'str'>

# %%
x = float(input())
print(x)
print(type(x))
# Out:
# 4.6
# 4.6
# <class 'float'>

# %%
x = input("Enter Your Name ")
x
# Out:
# Enter Your Name anas emad
# 'anas emad'

# %%
"""it's my name
asdsad"""
print("HELP")
# Out:
# HELP

# %%
s ="""Mohameds "phone" is new
adad"""
print(s)
# Out:
# Mohameds "phone" is new
# adad

# %%
x = input('''Enter Your Name's
asdasd
asdsadsad
asdsadsa''')

print("Hello",x,123,'WELCOME')
type(x)
# Out:
# Enter Your Name's
# asdasd
# asdsadsad
# asdsadsaanas
# Hello anas 123 WELCOME
# str

# %%
print(input())
# Out:
# ahmed
# ahmed

# %%
y = input()
x = int(y)
type(x)
# Out:
# 50
# int

# %% [markdown]
# ### WAP to enter 2 numbers from user and print addition of them.

# %%
a = input("Enter 1st Number: ")
b = input("Enter 2nd Number: ")

c = a + b

print(c)
# Out:
# Enter 1st Number: 15
# Enter 2nd Number: 20
# 1520

# %% [markdown]
# ### Type Casting

# %%
a = 10.5
b = int(a)
print(b)
# Out:
# 10

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
a = "10"
print(type(a))
b = int(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
"10" + "20"
# Out:
# '1020'

# %%
10 + 20
# Out:
# 30

# %%
"h"+10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-986cbe2142df> in <cell line: 1>()
# ----> 1 "h"+10
#
# TypeError: can only concatenate str (not "int") to str

# %%
3*'H'
# Out:
# 'HHH'

# %%
a = int(input("Enter 1st Number: "))
b = float(input("Enter 2nd Number: "))

c = a + b

print(c)
# Out:
# Enter 1st Number: 30
# Enter 2nd Number: 5.6
# 35.6

# %%
print(type(c))
# Out:
# <class 'int'>

# %%
print(a,"Hello",120,"world",True)
# Out:
# 10 Hello	 120 world True

# %%
a = int(input("Enter 1st Number: "))
b = int(input("Enter 2nd Number: "))

c = a + b

print("Addition = ", c)
# Out:
# Enter 1st Number: 10
# Enter 2nd Number: 20
# Addition =  30

# %%
a = input("Enter 1st Number: ")
b = input("Enter 2nd Number: ")

c = a + b

print("Addition = " + c)
# Out:
# Enter 1st Number: 10
# Enter 2nd Number: 20
# Addition = 1020

# %%
a = input("Enter 1st Number: ")
# Out:
# Enter 1st Number: 10

# %%
print(h)
# Out:
# H

# %% [markdown]
# # Task 1

# %% [markdown]
#  Solution is asdasd
